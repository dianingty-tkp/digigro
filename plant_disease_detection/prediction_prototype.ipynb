# %%
import warnings
warnings.simplefilter('ignore')
from models import DiseasePrediction

disease_prediction_model = DiseasePrediction()
# Out:
# 2023-06-15 04:41:23.527849: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-15 04:41:23.711783: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-06-15 04:41:24.390451: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2023-06-15 04:41:24.390552: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2023-06-15 04:41:24.390562: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-06-15 04:41:25.217971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-15 04:41:25.257318: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-15 04:41:25.259029: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-15 04:41:25.262381: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-15 04:41:25.264295: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-15 04:41:25.265989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-15 04:41:25.267605: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-15 04:41:26.071758: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-15 04:41:26.073406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-15 04:41:26.074801: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-15 04:41:26.076125: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12811 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %% [markdown]
# # One image example

# %%
image_path = "dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot/065fe7da-dcaf-41be-9332-5ec5ebceb94b___RS_GLSp 9337_270deg.JPG"
disease_prediction_model.predict(image_path)
# Out:
# 2023-06-15 04:41:34.665167: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8200
# Cercospora leaf spot
#
# Cercospora leaf spot, also known as gray leaf spot, is a fungal disease that affects corn (maize) plants, causing small, rectangular, gray or tan lesions on the leaves
#
# To manage this disease, it is recommended to plant resistant corn varieties, practice crop rotation, ensure proper spacing between plants for good air circulation, and apply fungicides if necessary. Additionally, removing and destroying crop debris after harvest can help reduce overwintering fungal spores.

# %% [markdown]
# # Random image example

# %%
from glob import glob
import numpy as np

# list down all images
image_list = glob("dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid/*/*")

# %%
# processed random image
# NOTE: the accuracy in this model is 0.8. Expect 2 misclassification out of 10
image_path = np.random.choice(image_list, 1)[0]
print("Path:", image_path, "\n\n")
disease_prediction_model.predict(image_path)
# Out:
# Path: dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid/Grape___Esca_(Black_Measles)/cc173e43-d13a-47aa-bb59-d4724d09e816___FAM_B.Msls 1842_flipLR.JPG
#
#
# Esca (Black Measles)
#
# Esca, also known as Black Measles, is a fungal disease that affects grapevines, causing black or brown streaks in the wood, leaf discoloration, and eventual vine decline.
#
# To manage Esca, it is important to implement preventive measures such as planting resistant grapevine varieties, practicing proper vineyard sanitation by removing infected wood and pruning wounds, and reducing stress factors like drought and nutrient imbalances. Regular monitoring, early detection, and prompt action are crucial in managing Esca and preserving grapevine health.
